# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

url1 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
url2 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
url3 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'

df1 = pd.read_csv(url1)
df2 =pd.read_csv(url2)
df3 =pd.read_csv(url3)

df = pd.concat([df1, df2, df3], axis=0)

df.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount State Gender
# ...

# %%
# columnas gender y state duplicadas, eliminan las que tienen mas valores nulos

print("Valores no nulos en 'State':", df['State'].notnull().sum())                  #7070
print("Valores no nulos en 'ST' (duplicada):", df['ST'].notnull().sum())            #2067
print("Valores no nulos en 'Gender':", df['Gender'].notnull().sum())                #7070
print("Valores no nulos en 'GENDER' (duplicada):", df['GENDER'].notnull().sum())    #1945

df = df.drop(columns=['ST', 'GENDER'])

df.head()
# Out:
# Valores no nulos en 'State': 7070
# Valores no nulos en 'ST' (duplicada): 2067
# Valores no nulos en 'Gender': 7070
# Valores no nulos en 'GENDER' (duplicada): 1945
#   Customer             Education Customer Lifetime Value   Income  \
# 0  RB50392                Master                     NaN      0.0
# 1  QZ44356              Bachelor              697953.59%      0.0
# 2  AI49188              Bachelor             1288743.17%  48767.0
# 3  WW63253              Bachelor              764586.18%      0.0
# 4  GA49547  High School or Below              536307.65%  36357.0
#
#    Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                1000.0                    1/0/00   Personal Auto
# 1                  94.0                    1/0/00   Personal Auto
# 2                 108.0                    1/0/00   Personal Auto
# 3                 106.0                    1/0/00  Corporate Auto
# 4                  68.0                    1/0/00   Personal Auto
#
# ...

# %%
import functions, importlib
importlib.reload(functions)

df_normalized = functions.normalize_column_names(df)

df_normalized.head(5)
# Out:
# Column names normalized
#   customer             education customer_lifetime_value   income  \
# 0  RB50392                Master                     NaN      0.0
# 1  QZ44356              Bachelor              697953.59%      0.0
# 2  AI49188              Bachelor             1288743.17%  48767.0
# 3  WW63253              Bachelor              764586.18%      0.0
# 4  GA49547  High School or Below              536307.65%  36357.0
#
#    monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                1000.0                    1/0/00   Personal Auto
# 1                  94.0                    1/0/00   Personal Auto
# 2                 108.0                    1/0/00   Personal Auto
# 3                 106.0                    1/0/00  Corporate Auto
# 4                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount state gender
# 0  Four-Door Car            2.704934   NaN    NaN
# ...

# %%
importlib.reload(functions)

df_cleaned = functions.clean_invalid_values(df_normalized)

df_cleaned
# Out:
# Inconsistent values replaced
#      customer             education  customer_lifetime_value   income  \
# 0     RB50392                Master                      NaN      0.0
# 1     QZ44356              Bachelor                697953.59      0.0
# 2     AI49188              Bachelor               1288743.17  48767.0
# 3     WW63253              Bachelor                764586.18      0.0
# 4     GA49547  High School or Below                536307.65  36357.0
# ...       ...                   ...                      ...      ...
# 7065  LA72316              Bachelor                      NaN  71941.0
# 7066  PK87824               College                      NaN  21604.0
# 7067  TD14365              Bachelor                      NaN      0.0
# 7068  UP19263               College                      NaN  21941.0
# 7069  Y167826               College                      NaN      0.0
#
#       monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
importlib.reload(functions)

df_removed = functions.remove_null_values(df_cleaned)
# Out:
# Columns with null or missing values:
# Index(['customer', 'education', 'customer_lifetime_value', 'income',
#        'monthly_premium_auto', 'number_of_open_complaints', 'policy_type',
#        'vehicle_class', 'total_claim_amount', 'state', 'gender'],
#       dtype='object')
# All null values have been successfully handled

# %%
print('there are', df_removed.duplicated(subset=['customer']).sum(), 'duplicados')           

print(df_removed[df_removed['customer'] == 'GA49547'])      # este de ejemplo
# Out:
# there are 3018 duplicados
#      customer             education  customer_lifetime_value   income  \
# 4     GA49547  High School or Below            536307.650000  36357.0
# 1870  GA49547  High School or Below            779946.308243  36357.0
#
#       monthly_premium_auto number_of_open_complaints    policy_type  \
# 4                     68.0                    1/0/00  Personal Auto
# 1870                  68.0                         0  Personal Auto
#
#       vehicle_class  total_claim_amount       state gender
# 4     Four-Door Car           17.269323  California      F
# 1870  Four-Door Car           17.269323  Washington      M

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
url4 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv'
df4 = pd.read_csv(url4)

full_df = pd.merge(df_removed, df4, on='customer', how='inner')

full_df.head()
# Out:
#   customer           education_x  customer_lifetime_value_x  income_x  \
# 0  RB50392                Master               7.799463e+05       0.0
# 1  QZ44356              Bachelor               6.979536e+05       0.0
# 2  AI49188              Bachelor               1.288743e+06   48767.0
# 3  WW63253              Bachelor               7.645862e+05       0.0
# 4  GA49547  High School or Below               5.363077e+05   36357.0
#
#    monthly_premium_auto_x number_of_open_complaints_x   policy_type_x  \
# 0                  1000.0                      1/0/00   Personal Auto
# 1                    94.0                      1/0/00   Personal Auto
# 2                   108.0                      1/0/00   Personal Auto
# 3                   106.0                      1/0/00  Corporate Auto
# 4                    68.0                      1/0/00   Personal Auto
#
#   vehicle_class_x  total_claim_amount_x     state_x  ... number_of_policies  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
pivot_df = full_df.pivot_table(index='sales_channel', columns='total_claim_amount_y', values='customer', aggfunc='sum')

full_df.describe()
# Out:
#        customer_lifetime_value_x      income_x  monthly_premium_auto_x  \
# count               1.384700e+04  13847.000000            13847.000000
# mean                7.818191e+05  37754.641380              110.529945
# std                 2.741875e+05  26940.089310              488.772529
# min                 2.004351e+05      0.000000               61.000000
# 25%                 7.799463e+05  20396.000000               71.000000
# 50%                 7.799463e+05  37828.820291               98.000000
# 75%                 7.799463e+05  55272.000000              110.391266
# max                 5.816655e+06  99981.000000            35354.000000
#
#        total_claim_amount_x    unnamed:_0  customer_lifetime_value_y  \
# count          13847.000000  13847.000000               13847.000000
# mean             431.151624   4485.848848                6829.647321
# std              258.638119   3359.201032                6466.874461
# ...

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
